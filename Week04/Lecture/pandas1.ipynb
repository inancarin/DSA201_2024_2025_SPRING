# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
obj = pd.Series([1,5, 10, 4])
obj
# Out:
# 0     1
# 1     5
# 2    10
# 3     4
# dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj.values
# Out:
# array([ 1,  5, 10,  4])

# %%
obj2 = pd.Series([4, 7, -5, 3], index=["d", "b", "a", "c"])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2["b"]
# Out:
# 7

# %%
obj2[["b", "a"]]
# Out:
# b    7
# a   -5
# dtype: int64

# %%
obj2 * 2
# Out:
# d     8
# b    14
# a   -10
# c     6
# dtype: int64

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2 > 0
# Out:
# d     True
# b     True
# a    False
# c     True
# dtype: bool

# %%
obj2.max()
# Out:
# 7

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
7 in obj2
# Out:
# False

# %%
"b" in obj2
# Out:
# True

# %%
7 in obj2.values
# Out:
# True

# %%
sdata = {"Istanbul": 18000000, "Izmir": 4500000,
         "Bursa": 1800000, "Ankara": 5500000}

obj3 = pd.Series(sdata)
obj3
# Out:
# Istanbul    18000000
# Izmir        4500000
# Bursa        1800000
# Ankara       5500000
# dtype: int64

# %%
sdata2 = {"Ankara": 6000000, "Istanbul": 20000000,
         "Izmir": 4800000, "Bursa": 2000000}

obj4 = pd.Series(sdata2)
obj4
# Out:
# Ankara       6000000
# Istanbul    20000000
# Izmir        4800000
# Bursa        2000000
# dtype: int64

# %%
(obj3 + obj4) / 2
# Out:
# Ankara       5750000.0
# Bursa        1900000.0
# Istanbul    19000000.0
# Izmir        4650000.0
# dtype: float64

# %%
d = {
    "Name": ["John", "Alice", "Jack", "Rose", "Alex", "David"],
    "Age": [32, 23, 21, 35, 45, 48],
    "City": ["Istanbul", "Paris", "London", "Madrid", "Sao Paulo", "Miami"]
}

data = pd.DataFrame(d)
data
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
data.shape
# Out:
# (6, 3)

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
data.values
# Out:
# array([['John', 32, 'Istanbul'],
#        ['Alice', 23, 'Paris'],
#        ['Jack', 21, 'London'],
#        ['Rose', 35, 'Madrid'],
#        ['Alex', 45, 'Sao Paulo'],
#        ['David', 48, 'Miami']], dtype=object)

# %%
data
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
data.head() # displays first 5 rows
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo

# %%
data.head(3)
# Out:
#     Name  Age      City
# 0   John   32  Istanbul
# 1  Alice   23     Paris
# 2   Jack   21    London

# %%
data.tail() # display last 5 rows
# Out:
#     Name  Age       City
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
data.tail(2)
# Out:
#     Name  Age       City
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
data["City"]
# Out:
# 0     Istanbul
# 1        Paris
# 2       London
# 3       Madrid
# 4    Sao Paulo
# 5        Miami
# Name: City, dtype: object

# %%
type(data["City"])
# Out:
# pandas.core.series.Series

# %%
data[["City", "Age"]]
# Out:
#         City  Age
# 0   Istanbul   32
# 1      Paris   23
# 2     London   21
# 3     Madrid   35
# 4  Sao Paulo   45
# 5      Miami   48

# %%
data["City"] # returns a Series object
# Out:
# 0     Istanbul
# 1        Paris
# 2       London
# 3       Madrid
# 4    Sao Paulo
# 5        Miami
# Name: City, dtype: object

# %%
data[["City"]]  # returns a DataFrame object
# Out:
#         City
# 0   Istanbul
# 1      Paris
# 2     London
# 3     Madrid
# 4  Sao Paulo
# 5      Miami

# %%
data.City # data["City"]
# Out:
# 0     Istanbul
# 1        Paris
# 2       London
# 3       Madrid
# 4    Sao Paulo
# 5        Miami
# Name: City, dtype: object

# %%
data.shape
# Out:
# (6, 3)

# %%
d
# Out:
# {'Name': ['John', 'Alice', 'Jack', 'Rose', 'Alex', 'David'],
#  'Age': [32, 23, 21, 35, 45, 48],
#  'City': ['Istanbul', 'Paris', 'London', 'Madrid', 'Sao Paulo', 'Miami']}

# %%
data
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
data["debt"] = 23.5
data
# Out:
#     Name  Age       City  debt
# 0   John   32   Istanbul  23.5
# 1  Alice   23      Paris  23.5
# 2   Jack   21     London  23.5
# 3   Rose   35     Madrid  23.5
# 4   Alex   45  Sao Paulo  23.5
# 5  David   48      Miami  23.5

# %%
data["Country"] = ["Turkiye", "France", "UK", "Spain", "Brazil", "US"]
data
# Out:
#     Name  Age       City  debt  Country
# 0   John   32   Istanbul  23.5  Turkiye
# 1  Alice   23      Paris  23.5   France
# 2   Jack   21     London  23.5       UK
# 3   Rose   35     Madrid  23.5    Spain
# 4   Alex   45  Sao Paulo  23.5   Brazil
# 5  David   48      Miami  23.5       US

# %%
data["Country"] = ["Turkiye", "France", "United Kingdom", "Spain", "Brazil", "US"]
data
# Out:
#     Name  Age       City  debt         Country
# 0   John   32   Istanbul  23.5         Turkiye
# 1  Alice   23      Paris  23.5          France
# 2   Jack   21     London  23.5  United Kingdom
# 3   Rose   35     Madrid  23.5           Spain
# 4   Alex   45  Sao Paulo  23.5          Brazil
# 5  David   48      Miami  23.5              US

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=[2, 4, 5])
data["debt"] = val
data
# Out:
#     Name  Age       City  debt         Country
# 0   John   32   Istanbul   NaN         Turkiye
# 1  Alice   23      Paris   NaN          France
# 2   Jack   21     London  -1.2  United Kingdom
# 3   Rose   35     Madrid   NaN           Spain
# 4   Alex   45  Sao Paulo  -1.5          Brazil
# 5  David   48      Miami  -1.7              US

# %%
data.drop("Name", axis=1)
# Out:
#    Age       City  debt         Country
# 0   32   Istanbul   NaN         Turkiye
# 1   23      Paris   NaN          France
# 2   21     London  -1.2  United Kingdom
# 3   35     Madrid   NaN           Spain
# 4   45  Sao Paulo  -1.5          Brazil
# 5   48      Miami  -1.7              US

# %%
data
# Out:
#     Name  Age       City  debt         Country
# 0   John   32   Istanbul   NaN         Turkiye
# 1  Alice   23      Paris   NaN          France
# 2   Jack   21     London  -1.2  United Kingdom
# 3   Rose   35     Madrid   NaN           Spain
# 4   Alex   45  Sao Paulo  -1.5          Brazil
# 5  David   48      Miami  -1.7              US

# %%
data.drop("Name", axis=1, inplace=True)

# %%
data
# Out:
#    Age       City  debt         Country
# 0   32   Istanbul   NaN         Turkiye
# 1   23      Paris   NaN          France
# 2   21     London  -1.2  United Kingdom
# 3   35     Madrid   NaN           Spain
# 4   45  Sao Paulo  -1.5          Brazil
# 5   48      Miami  -1.7              US

# %%
data.drop(["debt", "Country"], axis=1, inplace=True)
data
# Out:
#    Age       City
# 0   32   Istanbul
# 1   23      Paris
# 2   21     London
# 3   35     Madrid
# 4   45  Sao Paulo
# 5   48      Miami

# %%
data.drop(2, axis=0, inplace=True)
data
# Out:
#    Age       City
# 0   32   Istanbul
# 1   23      Paris
# 3   35     Madrid
# 4   45  Sao Paulo
# 5   48      Miami

# %%
data.index
# Out:
# Index([0, 1, 3, 4, 5], dtype='int64')

# %%
orders = pd.read_table("http://bit.ly/chiporders")
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.shape
# Out:
# (4622, 5)

# %%
orders.dtypes # data types
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
orders.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
orders.describe(include="object")
# Out:
#            item_name choice_description item_price
# count           4622               3376       4622
# unique            50               1043         78
# top     Chicken Bowl        [Diet Coke]     $8.75
# freq             726                134        730

# %%
orders.describe(include="all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
orders[["item_name", "choice_description"]].describe(include="object")
# Out:
#            item_name choice_description
# count           4622               3376
# unique            50               1043
# top     Chicken Bowl        [Diet Coke]
# freq             726                134

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.select_dtypes(include="object").head()
# Out:
#                                item_name  \
# 0           Chips and Fresh Tomato Salsa
# 1                                   Izze
# 2                       Nantucket Nectar
# 3  Chips and Tomatillo-Green Chili Salsa
# 4                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.select_dtypes(exclude="object").head()
# Out:
#    order_id  quantity
# 0         1         1
# 1         1         1
# 2         1         1
# 3         1         1
# 4         2         2

# %%
users = pd.read_table("http://bit.ly/movieusers",
                      header=None,
                      sep="|",
                      names=["ID", "Age", "Gender", "Occ", "Zip Code"])
#users.columns = ["ID", "Age", "Gender", "Occ", "Zip Code"]
users.head()
# Out:
#    ID  Age Gender         Occ Zip Code
# 0   1   24      M  technician    85711
# 1   2   53      F       other    94043
# 2   3   23      M      writer    32067
# 3   4   24      M  technician    43537
# 4   5   33      F       other    15213

# %%
users[["ID", "Gender", "Occ"]][:3]
# Out:
#    ID Gender         Occ
# 0   1      M  technician
# 1   2      F       other
# 2   3      M      writer

# %%
users[["ID", "Gender", "Occ"]].head(3)
# Out:
#    ID Gender         Occ
# 0   1      M  technician
# 1   2      F       other
# 2   3      M      writer

# %%
# users[["ID", "Gender", "Occ"]][:3] # changing the direction
users[:3][["ID", "Gender", "Occ"]]
# Out:
#    ID Gender         Occ
# 0   1      M  technician
# 1   2      F       other
# 2   3      M      writer

# %%
#movies = pd.read_table("http://bit.ly/imdbratings", sep=",")
movies = pd.read_csv("http://bit.ly/imdbratings")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies["duration"].sort_values(ascending=False)
# Out:
# 476    242
# 157    238
# 78     229
# 142    224
# 445    220
#       ...
# 293     68
# 88      68
# 258     67
# 338     66
# 389     64
# Name: duration, Length: 979, dtype: int64

# %%
# get the duration of the longest movie
movies["duration"].sort_values(ascending=False).values[0]
# Out:
# 242

# %%
# get the index of the longest movie
movies["duration"].sort_values(ascending=False).index[0]
# Out:
# 476

# %%
movies.sort_values("duration", ascending=False)
# Out:
#      star_rating                              title content_rating      genre  \
# 476          7.8                             Hamlet          PG-13      Drama
# 157          8.2                 Gone with the Wind              G      Drama
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# ..           ...                                ...            ...        ...
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 338          8.0                Battleship Potemkin        UNRATED    History
# 389          8.0                             Freaks        UNRATED      Drama
#
# ...

# %%
movies.sort_values("duration", ascending=False)["title"].values[0]
# Out:
# 'Hamlet'

# %%
movies.sort_values("duration", ascending=False)["title"].values[:3]
# Out:
# array(['Hamlet', 'Gone with the Wind', 'Once Upon a Time in America'],
#       dtype=object)

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.sort_values(["duration", "star_rating"])
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
movies.sort_values(["duration", "star_rating"], ascending=[True, False])
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 88           8.4                            The Kid      NOT RATED     Comedy
# 293          8.1                          Duck Soup         PASSED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
durations = []
for val in movies["duration"]:
    if val >= 180:
        durations.append(True)
    else:
        durations.append(False)

durations[:10]
# Out:
# [False, False, True, False, False, False, False, True, True, False]

# %%
movies[durations] # filtering
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 8            8.9                               Schindler's List
# 17           8.7                                  Seven Samurai
# 40           8.5                                 The Green Mile
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 89           8.4                                         Swades
# 93           8.4                    Dilwale Dulhania Le Jayenge
# 109          8.3                                 Dil Chahta Hai
# 132          8.3                          Judgment at Nuremberg
# 142          8.3              Lagaan: Once Upon a Time in India
# 143          8.2                        The Wolf of Wall Street
# 157          8.2                             Gone with the Wind
# ...

# %%
movies[movies["duration"] >= 180]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 8            8.9                               Schindler's List
# 17           8.7                                  Seven Samurai
# 40           8.5                                 The Green Mile
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 89           8.4                                         Swades
# 93           8.4                    Dilwale Dulhania Le Jayenge
# 109          8.3                                 Dil Chahta Hai
# 132          8.3                          Judgment at Nuremberg
# 142          8.3              Lagaan: Once Upon a Time in India
# 143          8.2                        The Wolf of Wall Street
# 157          8.2                             Gone with the Wind
# ...

# %%
movies[(movies["duration"] >= 180) & (movies["genre"] == "Action")]
# Out:
#      star_rating                            title content_rating   genre  \
# 385          8.0                        Spartacus          PG-13  Action
# 671          7.7                       Grindhouse              R  Action
# 767          7.6  It's a Mad, Mad, Mad, Mad World       APPROVED  Action
#
#      duration                                        actors_list
# 385       197  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...
# 671       191  [u'Kurt Russell', u'Rose McGowan', u'Danny Tre...
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
c1 = movies["duration"] >= 180
c2 = movies["genre"] == "Action"
movies[c1 & c2]
# Out:
#      star_rating                            title content_rating   genre  \
# 385          8.0                        Spartacus          PG-13  Action
# 671          7.7                       Grindhouse              R  Action
# 767          7.6  It's a Mad, Mad, Mad, Mad World       APPROVED  Action
#
#      duration                                        actors_list
# 385       197  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...
# 671       191  [u'Kurt Russell', u'Rose McGowan', u'Danny Tre...
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
c1 = movies["duration"] >= 180
c2 = (movies["genre"] == "Action") | (movies["genre"] == "Drama")
movies[c1 & c2]
# Out:
#      star_rating                            title content_rating   genre  \
# 17           8.7                    Seven Samurai        UNRATED   Drama
# 89           8.4                           Swades      NOT RATED   Drama
# 132          8.3            Judgment at Nuremberg      NOT RATED   Drama
# 157          8.2               Gone with the Wind              G   Drama
# 166          8.2                  The Deer Hunter              R   Drama
# 184          8.2              Fanny and Alexander              R   Drama
# 316          8.0                              JFK              R   Drama
# 318          8.0                         Magnolia              R   Drama
# 335          8.0                   Doctor Zhivago          PG-13   Drama
# 361          8.0              Fiddler on the Roof              G   Drama
# 385          8.0                        Spartacus          PG-13  Action
# 476          7.8                           Hamlet          PG-13   Drama
# ...

# %%
movies["genre"].isin(["Action", "Drama"])
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
c1 = movies["duration"] >= 180
c2 = movies["genre"].isin(["Action", "Drama"])
movies[c1 & c2]
# Out:
#      star_rating                            title content_rating   genre  \
# 17           8.7                    Seven Samurai        UNRATED   Drama
# 89           8.4                           Swades      NOT RATED   Drama
# 132          8.3            Judgment at Nuremberg      NOT RATED   Drama
# 157          8.2               Gone with the Wind              G   Drama
# 166          8.2                  The Deer Hunter              R   Drama
# 184          8.2              Fanny and Alexander              R   Drama
# 316          8.0                              JFK              R   Drama
# 318          8.0                         Magnolia              R   Drama
# 335          8.0                   Doctor Zhivago          PG-13   Drama
# 361          8.0              Fiddler on the Roof              G   Drama
# 385          8.0                        Spartacus          PG-13  Action
# 476          7.8                           Hamlet          PG-13   Drama
# ...

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders["item_price"].str.replace("$", "").astype(float).mean()
# Out:
# 7.464335785374297

# %%
orders["item_price"].str.slice(1).astype(float).mean()
# Out:
# 7.464335785374297

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# calculate the average item price of the items whose
# name contains "chicken" in any form "chicken", "Chicken"

temp_df = orders[orders["item_name"].str.lower().str.contains("chicken")]
temp_df["item_price"].str.replace("$", "").astype(float).mean()
# Out:
# 10.133724358974359

# %%
drinks = pd.read_csv("http://bit.ly/drinksbycountry")
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.sort_values("beer_servings", ascending=False)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
# ..              ...            ...              ...            ...
# 107      Mauritania              0                0              0
# 158         Somalia              0                0              0
# 111          Monaco              0                0              0
# 128        Pakistan              0                0              0
# 0       Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8    Africa
# 45                           11.8    Europe
# ...

# %%
# avg beer cons in Europe
drinks[drinks["continent"] == "Europe"]["beer_servings"].mean()
# Out:
# 193.77777777777777

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks["continent"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
for cont in drinks["continent"].unique():
    res = drinks[drinks["continent"] == cont]["beer_servings"].mean()
    print(cont, res)
# Out:
# Asia 37.04545454545455
# Europe 193.77777777777777
# Africa 61.471698113207545
# North America 145.43478260869566
# South America 175.08333333333334
# Oceania 89.6875

# %%
res = drinks.groupby("continent").mean(numeric_only=True)
res
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
res.index
# Out:
# Index(['Africa', 'Asia', 'Europe', 'North America', 'Oceania',
#        'South America'],
#       dtype='object', name='continent')

# %%
res.values
# Out:
# array([[ 61.47169811,  16.33962264,  16.26415094,   3.00754717],
#        [ 37.04545455,  60.84090909,   9.06818182,   2.17045455],
#        [193.77777778, 132.55555556, 142.22222222,   8.61777778],
#        [145.43478261, 165.73913043,  24.52173913,   5.99565217],
#        [ 89.6875    ,  58.4375    ,  35.625     ,   3.38125   ],
#        [175.08333333, 114.75      ,  62.41666667,   6.30833333]])

# %%
drinks.groupby("continent").mean(numeric_only=True)["beer_servings"]
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby("continent")["beer_servings"].mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby("continent")["beer_servings"].max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby("continent").size()
# Out:
# continent
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# dtype: int64

# %%
drinks.groupby("continent").max()
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# continent
# Africa               Zimbabwe            376              152            233
# Asia                    Yemen            247              326            123
# Europe         United Kingdom            361              373            370
# North America             USA            285              438            100
# Oceania               Vanuatu            306              254            212
# South America       Venezuela            333              302            221
#
#                total_litres_of_pure_alcohol
# continent
# Africa                                  9.1
# Asia                                   11.5
# Europe                                 14.4
# North America                          11.9
# Oceania                                10.4
# South America                           8.3

# %%
drinks.groupby("continent")["beer_servings"].mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby("continent")["beer_servings"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='continent'>

# %%
#plt.figure(figsize=(10, 6))
drinks.groupby("continent")["beer_servings"].mean().plot(kind="bar", figsize=(10,6))
plt.title("My Result")
plt.xticks(rotation=70)
plt.show()

# %%
drinks.groupby("continent").mean(numeric_only=True)
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
drinks.groupby("continent").mean(numeric_only=True).plot(kind="bar")
# Out:
# <Axes: xlabel='continent'>

# %%
drinks[drinks["continent"] == "South America"]
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 6                             8.3  South America
# 20                            3.8  South America
# ...

# %%
drinks[drinks["continent"] == "South America"].plot(kind="bar")
# Out:
# <Axes: >

# %%
drinks[drinks["continent"] == "South America"].plot(kind="bar", x="country")
# Out:
# <Axes: xlabel='country'>

# %%
drinks[drinks["continent"] == "South America"].plot(kind="bar", x="country", y="beer_servings")
# Out:
# <Axes: xlabel='country'>

# %%
temp = drinks[drinks["continent"] == "South America"]
plt.bar(temp["country"], temp["beer_servings"])
plt.xticks(rotation=90)
plt.show()

# %%
temp
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 6                             8.3  South America
# 20                            3.8  South America
# ...

# %%
temp.to_excel("result.xlsx")

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.groupby("continent").size() # returns a result sorted by index (alph)
# Out:
# continent
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# dtype: int64

# %%
drinks["continent"].value_counts() # returns the result sorted by freq
# Out:
# continent
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: count, dtype: int64

# %%
drinks.groupby("continent").size().sort_values(ascending=False)
# Out:
# continent
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# dtype: int64

# %%
drinks["continent"].value_counts().sort_index()
# Out:
# continent
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: count, dtype: int64

# %%
print()
